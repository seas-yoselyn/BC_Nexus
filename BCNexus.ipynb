# %% [markdown]
# Define Results Tag
# ---

# %% [markdown]
# - introduced on 2026 -07 -14, to avoid overlapping results for same configuration.
# - RUNTAG is handled automatically when scenario_pipeline is run. this notebook shows a demo on how this RUNTAG is being used to define paths.

# %%
from datetime import datetime
RUNTAG = datetime.now().strftime("%Y_%d_%m")

# %% [markdown]
# # <span style="color: Coral;"> Scenario config UI </span>

# %% [markdown]
# - Load the <span style="color: orange;"> _utils_ </span> module, which handles the backend functions to provide the <span style="color: blue;"> __scenario comnfig ui__ </span>

# %%
import bcnexus.utils as utils
import re # For regex operations
scenarios_dd, storage_algo_dd, h_grouping_dd, n_clusters_dd, timeslices_label = utils.build_scenario_ui()
# Out:
# VBox(children=(HTML(value="<h4 style='margin-bottom:3px;'>Scenario Selection</h4>"), HBox(children=(Dropdown(d…

# %% [markdown]
# - Assign the <span style="color: orange;"> __values__</span>  from <span style="color: blue;"> __scenario UI dropdowns__</span> to <span style="color: orange;"> __arguments__</span>

# %%
model_builder_args = dict(
    run_scenario=scenarios_dd.value ,
    storage_algorithm=storage_algo_dd.value,
    clustering_attributes=dict(
        hour_grouping=h_grouping_dd.value,
        n_clusters=n_clusters_dd.value
    )
)


# We use the Timeslices information to access run specific folders
timeslices_int = int(re.search(r'\d+', timeslices_label.value).group()) if re.search(r'\d+', timeslices_label.value) else None

# %% [markdown]
# # <span style="color: Coral;"> Model Runner Object </span>

# %% [markdown]
# * <span style="color: grey;">From `clews.runner` module, load the `RunModel` Object </span>

# %%
from bcnexus.clews.runner import RunModel

# %% [markdown]
# * <span style="color: grey;"> Create an instance of the `RunModel` Object `bcnexusRun` with __model_builder_args__ </span>

# %%
bcnexusRun = RunModel(**model_builder_args)
# Out:
# └> Initiated CLEWs Model Runner for 'Base_CNZ' scenario with 'Kotzur' storage algorithm
#  └>  Input CSVS set to: data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs
# ____________________________________________________________________________________________________
#      CLEWs Model Builder
# ____________________________________________________________________________________________________
# ******************
# Scenario: Base_CNZ
# ******************
# ℹ️  Using configuration file at: config/scenarios_bcnexus.yaml
# ℹ️  Clustering attributes: {'hour_grouping': 2, 'n_clusters': 1}
# ℹ️  Storage Algorithm: Kotzur
#  └> Extracting class attributes e.g. directories, static values/ranges, constants etc.
# bcnexus.attributes_parser | CLEWs snapshot configuration: start_year=2021, last_year=2040
# ℹ️  bcnexus.attributes_parser | BCNexus CLEWs model is structured as SINGLE region model. Current region set to: REGION1.
# ℹ️  bcnexus.attributes_parser | Fetching OTOOLE config from : models/model_Kotzur/otoole_config_Kotzur.yaml
#  └> checking input CSVs...
#  └> Copying missing CSV files : 'data/clews_data/csv_template' >> 'data/clews_data/clews_build_data/input_csvs'
#   └─> Skipped (already exists): ReserveMarginTagFuel.csv
#   └─> Skipped (already exists): DaySplit.csv
#   └─> Skipped (already exists): REMinProductionTarget.csv
#   └─> Skipped (already exists): RETagFuel.csv
#   └─> Skipped (already exists): ModelPeriodEmissionLimit.csv
#   └─> Skipped (already exists): MinStorageCharge.csv
#   └─> Skipped (already exists): OperationalLifeStorage.csv
#   └─> Skipped (already exists): TradeRoute.csv
#   └─> Skipped (already exists): TotalAnnualMaxCapacityInvestment.csv
#   └─> Skipped (already exists): DiscountRateStorage.csv
#   └─> Skipped (already exists): TechnologyToStorage.csv
#   └─> Skipped (already exists): DaysInDayType.csv
#   └─> Skipped (already exists): STORAGE.csv
#   └─> Skipped (already exists): CapitalCostStorage.csv
#   └─> Skipped (already exists): OperationalLife.csv
#   └─> Skipped (already exists): TotalTechnologyAnnualActivityLowerLimit.csv
#   └─> Skipped (already exists): Conversionls.csv
#   └─> Skipped (already exists): MODE_OF_OPERATION.csv
#   └─> Skipped (already exists): DAYSCRO.csv
#   └─> Skipped (already exists): TIMESLICE.csv
#   └─> Skipped (already exists): ReserveMargin.csv
#   └─> Skipped (already exists): StorageMaxDischargeRate.csv
#   └─> Skipped (already exists): CapitalCost.csv
#   └─> Skipped (already exists): TechnologyActivityByModeLowerLimit.csv
#   └─> Skipped (already exists): FixedCost.csv
#   └─> Skipped (already exists): CapacityFactor.csv
#   └─> Skipped (already exists): TechnologyFromStorage.csv
#   └─> Skipped (already exists): AvailabilityFactor.csv
#   └─> Skipped (already exists): DiscountRate.csv
#   └─> Skipped (already exists): ResidualCapacity.csv
#   └─> Skipped (already exists): OutputActivityRatio.csv
#   └─> Skipped (already exists): TotalTechnologyAnnualActivityUpperLimit.csv
#   └─> Skipped (already exists): StorageMaxChargeRate.csv
#   └─> Skipped (already exists): CapacityOfOneTechnologyUnit.csv
#   └─> Skipped (already exists): SEASON.csv
#   └─> Skipped (already exists): CapacityToActivityUnit.csv
#   └─> Skipped (already exists): VariableCost.csv
#   └─> Skipped (already exists): DAILYTIMEBRACKET.csv
#   └─> Skipped (already exists): Conversionlh.csv
#   └─> Skipped (already exists): InputActivityRatio.csv
#   └─> Skipped (already exists): EmissionActivityRatio.csv
#   └─> Skipped (already exists): DepreciationMethod.csv
#   └─> Skipped (already exists): FUEL.csv
#   └─> Skipped (already exists): DAYTYPE.csv
#   └─> Skipped (already exists): ResidualStorageCapacity.csv
#   └─> Skipped (already exists): RETagTechnology.csv
#   └─> Skipped (already exists): TechnologyActivityByModeUpperLimit.csv
#   └─> Skipped (already exists): Conversionld.csv
#   └─> Skipped (already exists): ModelPeriodExogenousEmission.csv
#   └─> Skipped (already exists): EmissionsPenalty.csv
#   └─> Skipped (already exists): EMISSION.csv
#   └─> Skipped (already exists): TotalAnnualMinCapacity.csv
#   └─> Skipped (already exists): Conversionldc.csv
#   └─> Skipped (already exists): SpecifiedDemandProfile.csv
#   └─> Skipped (already exists): YearSplit.csv
#   └─> Skipped (already exists): ReserveMarginTagTechnology.csv
#   └─> Skipped (already exists): TotalAnnualMinCapacityInvestment.csv
#   └─> Skipped (already exists): YEAR.csv
#   └─> Skipped (already exists): SpecifiedAnnualDemand.csv
#   └─> Skipped (already exists): TotalTechnologyModelPeriodActivityUpperLimit.csv
#   └─> Skipped (already exists): AccumulatedAnnualDemand.csv
#   └─> Skipped (already exists): TechnologyActivityIncreaseByModeLimit.csv
#   └─> Skipped (already exists): REGION.csv
#   └─> Skipped (already exists): AnnualEmissionLimit.csv
#   └─> Skipped (already exists): TotalTechnologyModelPeriodActivityLowerLimit.csv
#   └─> Skipped (already exists): TotalAnnualMaxCapacity.csv
#   └─> Skipped (already exists): TechnologyActivityDecreaseByModeLimit.csv
#   └─> Skipped (already exists): AnnualExogenousEmission.csv
#   └─> Skipped (already exists): TECHNOLOGY.csv
#  └> Checked and copied missing CSV files from data/clews_data/csv_template to data/clews_data/clews_build_data/input_csvs
# ℹ️  bcnexus.attributes_parser | Fetching OTOOLE config from : models/model_Kotzur/otoole_config_Kotzur.yaml
# bcnexus.attributes_parser | CLEWs snapshot configuration: start_year=2021, last_year=2040
# ℹ️  bcnexus.attributes_parser | BCNexus CLEWs model is structured as SINGLE region model. Current region set to: REGION1.
#  └> Calculating clustering attributes
#  └> No. of Timeslices configured= 12
#   └─> Representative days: [243]

# %% [markdown]
# ### 🚀 `run()` — Core Execution Workflow

# %% [markdown]
# * <span style="color: grey;"> Apply the `run()` method from  `bcnexusRun` instance </span> to run the complete workflow

# %% [markdown]
# About __Arguments__ of the `run()` method:
#
# - `build=True` argument handles the workflow run to build SETs, Ratios, template params etc.
# - `include_livestock` handles the livestock modelling workflow using `bcnexus/clews/livestock.py` module.
# - `thread` depends on the hardware limitations of your machine. If you have 4 core CPU, use Thread __<=4__ )

# %% [markdown]
# * <span style="color: skyblue;"> Where do I get `threads` number ?</span>
#   - <span style="color: grey;"> Apply the `check_machine_cores()` function from  `utils` module. it returns the __number of cores available__ </span>

# %%
n_physical_cores, n_logical_cores=utils.check_machine_cores()
# Out:
# ℹ️  Your machine has 24 physical cores and 32 logical cores.

# %% [markdown]
# | Model Characteristics                         | Recommended Threads | Reasoning                                                      |
# | --------------------------------------------- | ------------------- | -------------------------------------------------------------- |
# | Small LP/MILP (<50k vars)                     | 1–4                 | Over-parallelization adds overhead; single-thread often enough |
# | Medium MILP (50k–500k vars)                   | 4–8                 | Good balance of parallel speed-up and stability                |
# | Large/complex MILP (>500k vars, branch-heavy) | 8–16                | Parallel branch-and-bound scales moderately well               |
# | Nonlinear / Quadratic / MIQP                  | 4–8                 | Solvers often rely on sequential matrix operations             |
# | Highly degenerate or network-based LP         | 1–4                 | Parallel simplex often unstable; dual simplex preferred        |

# %% [markdown]
# * <span style="color: orange;">  Now run the Model ! </span>

# %% [markdown]
#  <span style="color: coral;"> Important Notes:
#   - While creating an instance of `RunModel` object (here named as `bcnexusRun`), it also creates an instance of `BuildModel` object (initiated and named as `ClewsBuilder` inside `RunModel` object ). You can access it via `bcnexusRun.ClewsBuilder`  , and access the methods inside `ClewsBuilder` object.
#   - The `ClewsBuilder` object can be found at </span> <span style="color: biege;"> bcnexus/clews/__builder.py__ module
#   - when we set `build=True`. We use the `build()` method of `ClewsBuilder` object.
#     - The `build()` method is useful to test/validate new structural changes to the model. This method handles the SETs creation, collection of LandCluster data, technology updates via clews_builder.yaml config. Refer to the script and the example workbook for more details on this object and methods.
#     - `ClewsBuilder` has an explicit method `build_SETs_and_ratios` which is an adaptation of the former __clewsy__ tool. Developers can use this method and add their custom methods to incorporate new structural changes to the model.

# %% [markdown]
# <span style="color: coral;"> Data flow in folder:</span>
#   - Everything happens inside : <span style="color: coral;"> data/clews_data</span>
#   - The workflow __creates this directory__ : <span style="color: coral;">data/clews_data/<span style="color: magenta;">clews_build_data </span><br>
#       <span style="color: grey;"> It has 3 sub-folders:
#       <span style="color: coral;">
#       - input_csvs  <span style="color: grey;">: The workflow collects templates data first, then updates the files accordingly to reflect changes in clews_builder.yaml config. <span style="color: red;"> if `build`=False, then the workflow assumes all files are updated in this folder. Once you build the model structure, to adjust the temporal clustering attributes only, you can set `build=False`, to skip the steps to build this folder.
#       - inputs_csv_8760<span style="color: grey;">: Creates BCNexus compatible profiling parameters in hourly resolution. Which are used to apply the clustering. <span style="color: red;"> if `build`=False, then the workflow assumes all files are updated in this folder.Once you build the model structure, to adjust the temporal clustering attributes only, you can set `build=False`, to skip the steps to build this folder.
#       - Model_storage_algorithm<span style="color: grey;">: Final datafiles are stored inside this folder with storage case, and sub-folders with scenarios.
#   - Once you build the model structure, yt adjust the clustering attributes only, you can set `build=False`, to skip the steps to build this folder.

# %%
bcnexusRun.run(build=True,
             include_livestock=False,
             threads=32)
# Out:
# └>  Running CLEWs Builder to prepare SETs and Params for scenario: Base_CNZ
#  └> checking input CSVs...
#  └> Copying all CSV files : 'data/clews_data/csv_template' >> 'data/clews_data/clews_build_data/input_csvs'
#   └> Copied: ReserveMarginTagFuel.csv
#   └> Copied: DaySplit.csv
#   └> Copied: REMinProductionTarget.csv
#   └> Copied: RETagFuel.csv
#   └> Copied: ModelPeriodEmissionLimit.csv
#   └> Copied: MinStorageCharge.csv
#   └> Copied: OperationalLifeStorage.csv
#   └> Copied: TradeRoute.csv
#   └> Copied: TotalAnnualMaxCapacityInvestment.csv
#   └> Copied: DiscountRateStorage.csv
#   └> Copied: TechnologyToStorage.csv
#   └> Copied: DaysInDayType.csv
#   └> Copied: STORAGE.csv
#   └> Copied: CapitalCostStorage.csv
#   └> Copied: OperationalLife.csv
#   └> Copied: TotalTechnologyAnnualActivityLowerLimit.csv
#   └> Copied: Conversionls.csv
#   └> Copied: MODE_OF_OPERATION.csv
#   └> Copied: DAYSCRO.csv
#   └> Copied: TIMESLICE.csv
#   └> Copied: ReserveMargin.csv
#   └> Copied: StorageMaxDischargeRate.csv
#   └> Copied: CapitalCost.csv
#   └> Copied: TechnologyActivityByModeLowerLimit.csv
#   └> Copied: FixedCost.csv
#   └> Copied: CapacityFactor.csv
#   └> Copied: TechnologyFromStorage.csv
#   └> Copied: AvailabilityFactor.csv
#   └> Copied: DiscountRate.csv
#   └> Copied: ResidualCapacity.csv
#   └> Copied: OutputActivityRatio.csv
#   └> Copied: TotalTechnologyAnnualActivityUpperLimit.csv
#   └> Copied: StorageMaxChargeRate.csv
#   └> Copied: CapacityOfOneTechnologyUnit.csv
#   └> Copied: SEASON.csv
#   └> Copied: CapacityToActivityUnit.csv
#   └> Copied: VariableCost.csv
#   └> Copied: DAILYTIMEBRACKET.csv
#   └> Copied: Conversionlh.csv
#   └> Copied: InputActivityRatio.csv
#   └> Copied: EmissionActivityRatio.csv
#   └> Copied: DepreciationMethod.csv
#   └> Copied: FUEL.csv
#   └> Copied: DAYTYPE.csv
#   └> Copied: ResidualStorageCapacity.csv
#   └> Copied: RETagTechnology.csv
#   └> Copied: TechnologyActivityByModeUpperLimit.csv
#   └> Copied: Conversionld.csv
#   └> Copied: ModelPeriodExogenousEmission.csv
#   └> Copied: EmissionsPenalty.csv
#   └> Copied: EMISSION.csv
#   └> Copied: TotalAnnualMinCapacity.csv
#   └> Copied: Conversionldc.csv
#   └> Copied: SpecifiedDemandProfile.csv
#   └> Copied: YearSplit.csv
#   └> Copied: ReserveMarginTagTechnology.csv
#   └> Copied: TotalAnnualMinCapacityInvestment.csv
#   └> Copied: YEAR.csv
#   └> Copied: SpecifiedAnnualDemand.csv
#   └> Copied: TotalTechnologyModelPeriodActivityUpperLimit.csv
#   └> Copied: AccumulatedAnnualDemand.csv
#   └> Copied: TechnologyActivityIncreaseByModeLimit.csv
#   └> Copied: REGION.csv
#   └> Copied: AnnualEmissionLimit.csv
#   └> Copied: TotalTechnologyModelPeriodActivityLowerLimit.csv
#   └> Copied: TotalAnnualMaxCapacity.csv
#   └> Copied: TechnologyActivityDecreaseByModeLimit.csv
#   └> Copied: AnnualExogenousEmission.csv
#   └> Copied: TECHNOLOGY.csv
#  └> Checked and copied missing CSV files from data/clews_data/csv_template to data/clews_data/clews_build_data/input_csvs
# └> Building SETs and Ratios data...
#  └> Collecting LandCluster data files...
# ⚠️  This model usages prepared LandCluster data. Ensure the data is prepared for the scenario being modelled.
# ℹ️  Landcluster data source: models/LandClusterData
#  └> Copying all CSV files : 'models/LandClusterData' >> 'data/clews_data/LandClusterData'
#   └> Copied: clustering_results_prc_BC1.csv
#   └> Copied: clustermap_table.csv
#   └> Copied: clustering_results_BC1.csv
#   └> Copied: clustering_results_evt_BC1.csv
#   └> Copied: clustering_results_cwd_BC1.csv
# *******************
# Building CLEWs SETs
# *******************
# ℹ️  Saving to directory: data/clews_data/SETs
# ℹ️  Model Structure: 'bcnexus/clews/model_structure.py'
#   └> Checking Land Cluster Data files...
#   └─> landcluser data source: data/clews_data/LandClusterData
#   └─> ✔ All cluster files for land region 'BC1' found.
# ⚠️  Warning:  Import fuel CRU created for fuel that is not used in any sector.
# ⚠️  Warning:  Import fuel COA created for fuel that is not used in any sector.
#  └> Writing SETs to data/clews_data/SETs
#   └> Writing YEAR to data/clews_data/SETs/YEAR.csv
#   └> Writing EMISSION to data/clews_data/SETs/EMISSION.csv
#   └> Writing REGION to data/clews_data/SETs/REGION.csv
#   └> Writing TECHNOLOGY to data/clews_data/SETs/TECHNOLOGY.csv
#   └> Writing FUEL to data/clews_data/SETs/FUEL.csv
#   └> Writing MODE_OF_OPERATION to data/clews_data/SETs/MODE_OF_OPERATION.csv
#   └> Writing Input Activity Ratios to data/clews_data/SETs/InputActivityRatio.csv
#   └> Writing Output Activity Ratios to data/clews_data/SETs/OutputActivityRatio.csv
# **************************
# Limitations of build SETs:
# **************************
# ⚠️  'INFLOW' fuel and the associated activity ratios are handled separately.
# ⚠️  Storage algorithm associated explicit sets are handled separately.
#  └> Copying all CSV files : 'data/clews_data/SETs' >> 'data/clews_data/clews_build_data/input_csvs'
#   └> Copied: MODE_OF_OPERATION.csv
#   └> Copied: OutputActivityRatio.csv
#   └> Copied: InputActivityRatio.csv
#   └> Copied: FUEL.csv
#   └> Copied: EMISSION.csv
#   └> Copied: YEAR.csv
#   └> Copied: REGION.csv
#   └> Copied: TECHNOLOGY.csv
#  └> Updating 'clews_builder.config' to match data and user configurations (aggregation and naming of the TECHNOLOGIES).
#  └> Updating CLEWS Builder configuration file...
#   └> File Updated : config/clews_builder.yaml
# ℹ️  Reloading the updated clews_builder configuration...
#  └> updating SETs and Parameters inside data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs
#  └> Preparing profiling parameters for BCNexus
# ℹ️  Capacity Factor profiles file already exists. Skipping update.
# ℹ️  Demand profiles file already exists. Skipping update.
# └> updating temporal profiles
#  └> Calculating clustering attributes
#  └> No. of Timeslices configured= 12
#   └─> Representative days: [243]
#  └> Updating profiling parameters (CF,SDP) with user configured clusters
#   └> File Updated: data/clews_data/clews_build_data/input_csvs/CapacityFactor.csv
#   └> File Updated: data/clews_data/clews_build_data/input_csvs/SpecifiedDemandProfile.csv
#  └> Checking SETs (TECHNOLOGY, STORAGE) to harmonize clews builder configuration
#   └> Harmonizing data/clews_data/clews_build_data/input_csvs/TECHNOLOGY.csv with clews builder configuration
#   └─> Updated data/clews_data/clews_build_data/input_csvs/TECHNOLOGY.csv with new keys ['CCS01', 'HDG02', 'INFLOW01']
#   └> Harmonizing data/clews_data/clews_build_data/input_csvs/STORAGE.csv with clews builder configuration
#   └─> data/clews_data/clews_build_data/input_csvs/STORAGE.csv checked.
#  └> Updating yearly params' data
#   └> Using provided CLEWs Builder Config.
#   └> Updating OPERATIONAL LIFE...
#   └─> Disregarding HDG02 as it is empty
#   └─> Disregarding PWRGEOB01 as it is empty
#   └─> Disregarding PWRURNB01 as it is empty
#   └─> File updated: data/clews_data/clews_build_data/input_csvs/OperationalLife.csv
#   └─> File Updated : data/clews_data/clews_build_data/input_csvs/OperationalLifeStorage.csv
#   └> Updating AVAILABILITY FACTOR...
#   └─> Disregarding HDG02 as it is empty
#   └─> Disregarding PWRGEOB01 as it is empty
#   └─> Disregarding PWRURNB01 as it is empty
#   └─> updated: data/clews_data/clews_build_data/input_csvs/AvailabilityFactor.csv
#   └> Updating CAPITAL COST...
#   └─> Disregarding HDG02 as it is empty
#   └─> Disregarding PWRGEOB01 as it is empty
#   └─> Disregarding PWRURNB01 as it is empty
#   └─> updated: data/clews_data/clews_build_data/input_csvs/CapitalCost.csv
#   └─> updated: data/clews_data/clews_build_data/input_csvs/CapitalCostStorage.csv
#   └> Updating VARIABLE COST...
#   └─> Disregarding HDG02 as it is empty
#   └─> Disregarding PWRGEOB01 as it is empty
#   └─> Disregarding PWRURNB01 as it is empty
#   └─> updated: data/clews_data/clews_build_data/input_csvs/VariableCost.csv
#   └> Updating TECHNOLOGY FROM STORAGE...
#   └─> updated: data/clews_data/clews_build_data/input_csvs/TechnologyToStorage.csv
#   └─> updated : data/clews_data/clews_build_data/input_csvs/TechnologyFromStorage.csv
#   └> Updating TOTAL ANNUAL MAX CAPACITY...
#   └─> Disregarding HDG02 as it is empty
#   └─> Disregarding PWRGEOB01 as it is empty
#   └─> Disregarding PWRURNB01 as it is empty
#   └─> File Updated: data/clews_data/clews_build_data/input_csvs/TotalAnnualMaxCapacity.csv
#  └> Updating Global params' data
#   └> File updated: data/clews_data/clews_build_data/input_csvs/CapacityToActivityUnit.csv
#  └> Harmonizing the snapshot [2021-2040] for YEAR set and all Params associated to this set.
#   └> [i] The snapshot is configured via clews_model_constraint.py module's 'snapshot' dictionary.
# └> Loaded 43 CSV files from data/clews_data/clews_build_data/input_csvs
#   └─> 10 non-empty SETs loaded
#   └─> 33 non-empty Params loaded
# └> Updating Otoole config file...
#  └> DaySplit param added to models/model_Kotzur/otoole_config_Kotzur.yaml
#  └> ResidualStorageCapacity param added to models/model_Kotzur/otoole_config_Kotzur.yaml
#  └> Preparing profiling parameters for BCNexus
# ℹ️  Capacity Factor profiles file already exists. Skipping update.
# ℹ️  Demand profiles file already exists. Skipping update.
# └> updating temporal profiles
#  └> Calculating clustering attributes
#  └> No. of Timeslices configured= 12
#   └─> Representative days: [243]
#  └> Updating profiling parameters (CF,SDP) with user configured clusters
#   └> File Updated: data/clews_data/clews_build_data/input_csvs/CapacityFactor.csv
#   └> File Updated: data/clews_data/clews_build_data/input_csvs/SpecifiedDemandProfile.csv
#  └> Copying all CSV files : 'data/clews_data/clews_build_data/input_csvs' >> 'data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs'
#   └> Copied: ReserveMarginTagFuel.csv
#   └> Copied: DaySplit.csv
#   └> Copied: REMinProductionTarget.csv
#   └> Copied: RETagFuel.csv
#   └> Copied: ModelPeriodEmissionLimit.csv
#   └> Copied: MinStorageCharge.csv
#   └> Copied: OperationalLifeStorage.csv
#   └> Copied: TradeRoute.csv
#   └> Copied: TotalAnnualMaxCapacityInvestment.csv
#   └> Copied: DiscountRateStorage.csv
#   └> Copied: TechnologyToStorage.csv
#   └> Copied: DaysInDayType.csv
#   └> Copied: STORAGE.csv
#   └> Copied: CapitalCostStorage.csv
#   └> Copied: OperationalLife.csv
#   └> Copied: TotalTechnologyAnnualActivityLowerLimit.csv
#   └> Copied: Conversionls.csv
#   └> Copied: MODE_OF_OPERATION.csv
#   └> Copied: DAYSCRO.csv
#   └> Copied: TIMESLICE.csv
#   └> Copied: ReserveMargin.csv
#   └> Copied: StorageMaxDischargeRate.csv
#   └> Copied: CapitalCost.csv
#   └> Copied: TechnologyActivityByModeLowerLimit.csv
#   └> Copied: FixedCost.csv
#   └> Copied: CapacityFactor.csv
#   └> Copied: TechnologyFromStorage.csv
#   └> Copied: AvailabilityFactor.csv
#   └> Copied: DiscountRate.csv
#   └> Copied: ResidualCapacity.csv
#   └> Copied: OutputActivityRatio.csv
#   └> Copied: TotalTechnologyAnnualActivityUpperLimit.csv
#   └> Copied: StorageMaxChargeRate.csv
#   └> Copied: CapacityOfOneTechnologyUnit.csv
#   └> Copied: SEASON.csv
#   └> Copied: CapacityToActivityUnit.csv
#   └> Copied: VariableCost.csv
#   └> Copied: DAILYTIMEBRACKET.csv
#   └> Copied: Conversionlh.csv
#   └> Copied: InputActivityRatio.csv
#   └> Copied: EmissionActivityRatio.csv
#   └> Copied: DepreciationMethod.csv
#   └> Copied: FUEL.csv
#   └> Copied: DAYTYPE.csv
#   └> Copied: ResidualStorageCapacity.csv
#   └> Copied: RETagTechnology.csv
#   └> Copied: TechnologyActivityByModeUpperLimit.csv
#   └> Copied: Conversionld.csv
#   └> Copied: ModelPeriodExogenousEmission.csv
#   └> Copied: EmissionsPenalty.csv
#   └> Copied: EMISSION.csv
#   └> Copied: TotalAnnualMinCapacity.csv
#   └> Copied: Conversionldc.csv
#   └> Copied: SpecifiedDemandProfile.csv
#   └> Copied: YearSplit.csv
#   └> Copied: ReserveMarginTagTechnology.csv
#   └> Copied: TotalAnnualMinCapacityInvestment.csv
#   └> Copied: YEAR.csv
#   └> Copied: SpecifiedAnnualDemand.csv
#   └> Copied: TotalTechnologyModelPeriodActivityUpperLimit.csv
#   └> Copied: AccumulatedAnnualDemand.csv
#   └> Copied: TechnologyActivityIncreaseByModeLimit.csv
#   └> Copied: REGION.csv
#   └> Copied: AnnualEmissionLimit.csv
#   └> Copied: TotalTechnologyModelPeriodActivityLowerLimit.csv
#   └> Copied: TotalAnnualMaxCapacity.csv
#   └> Copied: TechnologyActivityDecreaseByModeLimit.csv
#   └> Copied: AnnualExogenousEmission.csv
#   └> Copied: TECHNOLOGY.csv
#   └> File Updated: data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/TIMESLICE.csv
#   └> File Updated: data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/DAYTYPE.csv
#   └> File Updated: data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/YearSplit.csv
#   └> File Updated: data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/DAYSCRO.csv
#   └> File Updated: data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/Conversionld.csv
#   └> File Updated: data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/Conversionldc.csv
# └>  Loading scenario config @ {'Demand': {}, 'EMISSION': {}, 'TECHS': {'CCS01': {'capital_cost': 9999, 'total_annual_max_capacity': 0.2, 'operational_life': 25, 'total_annual_max_capacity_investment': [0, 0, 0, 0, 0, 1]}, 'HDG01': {'operational_life': 25, 'total_annual_max_capacity': 0.2, 'total_annual_max_capacity_investment': [0, 0, 0, 0, 0, 1]}}}
#   └─> Processing Scenario Data...
#   └─> File Updated: data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/TECHNOLOGY.csv
#   └─> File Updated : config/clews_builder.yaml
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └─> Data updated for CCS01 in : data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/CapitalCost.csv
#   └─> Data updated for HDG01 in : data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/CapitalCost.csv
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └─> Data updated for CCS01 in : data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/OperationalLife.csv
#   └─> Data updated for HDG01 in : data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/OperationalLife.csv
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └─> Data updated for CCS01 in : data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/TotalAnnualMaxCapacityInvestment.csv
#   └─> Data updated for HDG01 in : data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/TotalAnnualMaxCapacityInvestment.csv
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └─> Data updated for CCS01 in : data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/TotalAnnualMaxCapacity.csv
#   └─> Data updated for HDG01 in : data/clews_data/clews_build_data/Model_Kotzur/storage_case_input_csvs/TotalAnnualMaxCapacity.csv
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └> Processing category: Demand
#   └> Processing category: EMISSION
#   └> Processing category: TECHS
#   └─> Scenario Data processing completed.Loading updated ClewsBuilder configuration...
#   └─> ClewsBuilder configuration reloaded from config/clews_builder.yaml
#  └> Timeslices: 12
# └> Preparing model and data files.
# DATA_INFILE: data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ_data.txt IS_DIR? False
#  └> Preprocessing data and model file for case: Kotzur
#   └> data file processed and saved as : data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ_dataProcessed.txt
#   └> model file processed and saved as : data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Kotzur_Model_processed.txt
# └> Preparing the LP file
#  └> Creating LP file: data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ.lp from Model : data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Kotzur_Model_processed.txt, Data : data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ_dataProcessed.txt
#  ─> GLPSOL: GLPK LP/MIP Solver, v4.65
#  ─> Parameter(s) specified in the command line:
#  ─> -m data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Kotzur_Model_processed.txt
#  ─> -d data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ_dataProcessed.txt
#  ─> --wlp data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ.lp
#  ─> --check
#  ─> Reading model section from data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Kotzur_Model_processed.txt...
#  ─> 214 lines were read
#  ─> Reading data section from data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ_dataProcessed.txt...
#  ─> data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ_dataProcessed.txt:73242: warning: final NL missing before end of file
#  ─> 73242 lines were read
#  ─> Generating cost...
#  ─> Generating CAa1_TotalNewCapacity...
#  ─> Generating CAa2_TotalAnnualCapacity...
#  ─> Generating CAa3_TotalActivityOfEachTechnology...
#  ─> Generating CAa4_Constraint_Capacity...
#  ─> Generating CAa5_TotalNewCapacity...
#  ─> Generating CAb1_PlannedMaintenance...
#  ─> Generating EBa9_EnergyBalanceEachTS3...
#  ─> Generating EBa10_EnergyBalanceEachTS4...
#  ─> Generating EBa11_EnergyBalanceEachTS5...
#  ─> Generating EBb4_EnergyBalanceEachYear4...
#  ─> Generating Acc3_AverageAnnualRateOfActivity...
#  ─> Generating S2_StorageLevelDayTypeFinish...
#  ─> Generating S1_StorageLevelYearStart...
#  ─> Generating S3_StorageLevelChronoDayStart...
#  ─> Generating SC4_StorageRefilling...
#  ─> Generating SC1_LowerLimit...
#  ─> Generating SC2_UpperLimit...
#  ─> Generating SI6_SalvageValueStorageAtEndOfPeriod1...
#  ─> Generating SI7_SalvageValueStorageAtEndOfPeriod2...
#  ─> Generating SI8_SalvageValueStorageAtEndOfPeriod3...
#  ─> Generating SI9_SalvageValueStorageDiscountedToStartYear...
#  ─> Generating CC1_UndiscountedCapitalInvestment...
#  ─> Generating SV1_SalvageValueAtEndOfPeriod1...
#  ─> Generating SV2_SalvageValueAtEndOfPeriod2...
#  ─> Generating SV3_SalvageValueAtEndOfPeriod3...
#  ─> Generating SV4_SalvageValueDiscountedToStartYear...
#  ─> Generating OC1_OperatingCostsVariable...
#  ─> Generating OC2_OperatingCostsFixedAnnual...
#  ─> Generating TCC1_TotalAnnualMaxCapacityConstraint...
#  ─> Generating TCC2_TotalAnnualMinCapacityConstraint...
#  ─> Generating NCC1_TotalAnnualMaxNewCapacityConstraint...
#  ─> Generating NCC2_TotalAnnualMinNewCapacityConstraint...
#  ─> Generating AAC2_TotalAnnualTechnologyActivityUpperLimit...
#  ─> Generating AAC3_TotalAnnualTechnologyActivityLowerLimit...
#  ─> Generating AAC1_TotalAnnualTechnologyActivity...
#  ─> Generating TAC2_TotalModelHorizonTechnologyActivityUpperLimit...
#  ─> Generating TAC3_TotalModelHorizonTechnologyActivityLowerLimit...
#  ─> Generating TAC1_TotalModelHorizonTechnologyActivity...
#  ─> Generating RM3_ReserveMargin_Constraint...
#  ─> Generating RE4_EnergyConstraint...
#  ─> Generating E5_DiscountedEmissionsPenaltyByTechnology...
#  ─> Generating E8_AnnualEmissionsLimit...
#  ─> Generating E9_ModelPeriodEmissionsLimit...
#  ─> Generating E1_AnnualEmissionProductionByMode...
#  ─> Generating E2_AnnualEmissionProduction...
#  ─> Generating E6_EmissionsAccounting1...
#  ─> Generating E7_EmissionsAccounting2...
#  ─> Generating LU1_TechnologyActivityByModeUL...
#  ─> Generating LU2_TechnologyActivityByModeLL...
#  ─> Generating LU3_TechnologyActivityIncreaseByMode...
#  ─> Generating LU4_TechnologyActivityDecreaseByMode...
#  ─> Model has been successfully generated
#  ─> glp_mpl_build_prob: row cost; constant term 8531.48418622 ignored
#  ─> Writing problem data to 'data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ.lp'...
#  ─> 3294119 lines were written
#  ─> --- Problem Characteristics ---
#  ─> Number of rows               =   298956
#  ─> Number of columns            =   316460
#  ─> Number of non-zeros (matrix) =  2923275
#  ─> Number of non-zeros (objrow) =    23820
# └> Solving the LP problem with <module 'bcnexus.clews.solver' from '/local-scratch/localhome/mei3/eliasinul/work/BC_Nexus/bcnexus/clews/solver.py'> solver
#  └> Using 32 threads to solve the model using Gurobi solver. If the solver fails to load/run due to memory issues, please use thread < your hardware limitation (cores)
#   └> Gurobi update :
#
#   └> --------------------------------------------------
# Set parameter Username
# 2026-07-14 05:40:02,994 - INFO - Set parameter Username
# Set parameter LicenseID to value 2812656
# 2026-07-14 05:40:02,994 - INFO - Set parameter LicenseID to value 2812656
# Academic license - for non-commercial use only - expires 2027-04-23
# 2026-07-14 05:40:02,997 - INFO - Academic license - for non-commercial use only - expires 2027-04-23
# Read LP format model from file data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ.lp
# 2026-07-14 05:40:04,061 - INFO - Read LP format model from file data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ/Base_CNZ.lp
# Reading time = 1.06 seconds
# 2026-07-14 05:40:04,061 - INFO - Reading time = 1.06 seconds
# cost: 298955 rows, 316460 columns, 2899455 nonzeros
# 2026-07-14 05:40:04,062 - INFO - cost: 298955 rows, 316460 columns, 2899455 nonzeros
# Set parameter LogToConsole to value 0
# 2026-07-14 05:40:04,062 - INFO - Set parameter LogToConsole to value 0
# 2026-07-14 05:40:04,062 - INFO - Set parameter Method to value 2
# 2026-07-14 05:40:04,062 - INFO - Set parameter Threads to value 32
# 2026-07-14 05:40:04,062 - INFO - Set parameter NumericFocus to value 2
# 2026-07-14 05:40:04,062 - INFO - Set parameter BarHomogeneous to value 1
# 2026-07-14 05:40:04,062 - INFO - Set parameter LogFile to value "results/clews/Model_Kotzur_Base_CNZ/12ts/gurobi.log"
# 2026-07-14 05:40:04,063 - INFO - Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (linux64 - "Ubuntu 20.04.6 LTS")
# 2026-07-14 05:40:04,063 - INFO -
# 2026-07-14 05:40:04,063 - INFO - CPU model: 13th Gen Intel(R) Core(TM) i9-13900K, instruction set [SSE2|AVX|AVX2]
# 2026-07-14 05:40:04,063 - INFO - Thread count: 32 physical cores, 32 logical processors, using up to 32 threads
# 2026-07-14 05:40:04,063 - INFO -
# 2026-07-14 05:40:04,063 - INFO - Non-default parameters:
# 2026-07-14 05:40:04,063 - INFO - Method  2
# 2026-07-14 05:40:04,064 - INFO - BarHomogeneous  1
# 2026-07-14 05:40:04,064 - INFO - LogToConsole  0
# 2026-07-14 05:40:04,064 - INFO - NumericFocus  2
# 2026-07-14 05:40:04,064 - INFO - Threads  32
# 2026-07-14 05:40:04,064 - INFO -
# 2026-07-14 05:40:04,064 - INFO - Optimize a model with 298955 rows, 316460 columns and 2899455 nonzeros
# 2026-07-14 05:40:04,075 - INFO - Model fingerprint: 0xb7d1b5d5
# 2026-07-14 05:40:04,078 - INFO - Coefficient statistics:
# 2026-07-14 05:40:04,078 - INFO -   Matrix range     [3e-08, 1e+06]
# 2026-07-14 05:40:04,078 - INFO -   Objective range  [3e-05, 2e+08]
# 2026-07-14 05:40:04,079 - INFO -   Bounds range     [0e+00, 0e+00]
# 2026-07-14 05:40:04,079 - INFO -   RHS range        [1e-05, 1e+08]
# 2026-07-14 05:40:04,079 - INFO - Warning: Model contains large matrix coefficient range
# 2026-07-14 05:40:04,411 - INFO - Presolve removed 221908 rows and 175871 columns
# 2026-07-14 05:40:04,415 - INFO - Presolve time: 0.35s
# 2026-07-14 05:40:04,415 - INFO - Presolved: 77047 rows, 140605 columns, 1498384 nonzeros
# 2026-07-14 05:40:04,415 - INFO -
# 2026-07-14 05:40:06,701 - INFO - Ordering time: 2.09s
# 2026-07-14 05:40:06,869 - INFO -
# 2026-07-14 05:40:06,870 - INFO - Barrier statistics:
# 2026-07-14 05:40:06,870 - INFO -  Dense cols : 80
# 2026-07-14 05:40:06,871 - INFO -  Free vars  : 20
# 2026-07-14 05:40:06,871 - INFO -  AA' NZ     : 3.640e+06
# 2026-07-14 05:40:06,871 - INFO -  Factor NZ  : 3.073e+07 (roughly 340 MB of memory)
# 2026-07-14 05:40:06,872 - INFO -  Factor Ops : 5.277e+10 (less than 1 second per iteration)
# 2026-07-14 05:40:06,872 - INFO -  Threads    : 32
# 2026-07-14 05:40:07,116 - INFO -
# 2026-07-14 05:40:07,117 - INFO -                   Objective                Residual
# 2026-07-14 05:40:07,117 - INFO - Iter       Primal          Dual         Primal    Dual     Compl     Time
# 2026-07-14 05:40:07,121 - INFO -    0   1.69942809e+17 -4.40810044e+14  2.80e+11 3.19e+00  8.65e+13     3s
# 2026-07-14 05:40:07,510 - INFO -    1   1.69942809e+17 -4.40810044e+14  2.80e+11 3.19e+00  8.65e+13     3s
# 2026-07-14 05:40:08,248 - INFO -    2   1.36955902e+17 -4.29804711e+14  1.96e+11 1.85e+05  7.05e+13     4s
# 2026-07-14 05:40:09,250 - INFO -    3   9.69374470e+16 -3.94846269e+14  1.09e+11 1.38e+05  4.51e+13     5s
# 2026-07-14 05:40:10,078 - INFO -    4   6.97796640e+15 -1.55899133e+14  8.96e+09 1.18e+04  4.93e+11     6s
# 2026-07-14 05:40:11,044 - INFO -    5   2.53464039e+15 -3.37283453e+13  3.08e+09 3.06e+03  9.50e+10     7s
# 2026-07-14 05:42:09,152 - INFO -  120   5.53022169e+04  5.52888524e+04  5.90e-05 1.09e-05  2.82e-06   125s
# 2026-07-14 05:42:10,242 - INFO -  121   5.53021313e+04  5.52888440e+04  5.88e-05 1.27e-03  2.81e-06   126s
# 2026-07-14 05:42:11,325 - INFO -  122   5.53021313e+04  5.52888439e+04  5.88e-05 1.31e-03  2.81e-06   127s
# 2026-07-14 05:42:13,214 - INFO -  123   5.52976885e+04  5.52850319e+04  9.03e-05 1.06e-03  2.62e-06   129s
# 2026-07-14 05:42:14,257 - INFO -  124   5.52951267e+04  5.52780610e+04  8.27e-05 6.66e-04  2.76e-06   130s
# 2026-07-14 05:42:15,217 - INFO -  125   5.52921815e+04  5.52736768e+04  7.48e-05 4.57e-04  2.62e-06   131s
# 2026-07-14 05:42:15,220 - INFO -
# 2026-07-14 05:42:15,220 - INFO - Barrier performed 125 iterations in 131.15 seconds (228.92 work units)
# 2026-07-14 05:42:15,220 - INFO - Sub-optimal termination - objective 5.53154638e+04
# 2026-07-14 05:42:15,220 - INFO -
# 2026-07-14 05:42:15,242 - INFO - Crossover log...
# 2026-07-14 05:42:15,242 - INFO -
# 2026-07-14 05:42:15,263 - INFO -    36260 DPushes remaining with DInf 0.0000000e+00               131s
# 2026-07-14 05:42:15,601 - INFO -        0 DPushes remaining with DInf 0.0000000e+00               132s
# 2026-07-14 05:42:15,627 - INFO -
# 2026-07-14 05:42:15,627 - INFO -   111502 PPushes remaining with PInf 1.3697903e-02               132s
# 2026-07-14 05:42:17,750 - INFO -        0 PPushes remaining with PInf 3.5796139e+04               134s
# 2026-07-14 05:42:17,756 - INFO -
# 2026-07-14 05:42:17,756 - INFO -   Push phase complete: Pinf 3.5796139e+04, Dinf 1.2529061e+04    134s
# 2026-07-14 05:42:17,757 - INFO -
# 2026-07-14 05:42:17,783 - INFO - Iteration    Objective       Primal Inf.    Dual Inf.      Time
# 2026-07-14 05:42:17,784 - INFO -   134808    4.8579301e+04   0.000000e+00   1.252906e+04    134s
# 2026-07-14 05:42:19,284 - INFO -   135469    4.8579300e+04   0.000000e+00   2.425352e+06    135s
# 2026-07-14 05:42:24,329 - INFO -   137569    4.8579201e+04   0.000000e+00   8.804226e+07    140s
# 2026-07-14 05:42:29,317 - INFO -   140070    4.8577517e+04   0.000000e+00   1.945665e+08    145s
# 2026-07-14 05:42:34,176 - INFO -   142918    4.7774516e+04   0.000000e+00   2.931960e+06    150s
# 2026-07-14 05:42:39,184 - INFO -   145460    4.7675401e+04   0.000000e+00   4.046419e+07    155s
# 2026-07-14 05:42:44,093 - INFO -   147871    4.7661522e+04   0.000000e+00   8.120612e+07    160s
# 2026-07-14 05:42:49,192 - INFO -   150381    4.7655445e+04   0.000000e+00   6.262972e+08    165s
# 2026-07-14 05:42:54,070 - INFO -   153375    4.7643035e+04   0.000000e+00   4.092375e+06    170s
# 2026-07-14 05:42:59,265 - INFO -   156623    4.7603481e+04   0.000000e+00   1.119593e+07    175s
# 2026-07-14 05:43:04,138 - INFO -   159945    4.7514922e+04   0.000000e+00   4.476279e+08    180s
# 2026-07-14 05:43:09,293 - INFO -   163085    4.7203922e+04   0.000000e+00   2.016084e+05    185s
# 2026-07-14 05:43:14,099 - INFO -   166334    4.7107962e+04   0.000000e+00   1.118772e+08    190s
# 2026-07-14 05:43:19,149 - INFO -   169915    4.6837462e+04   0.000000e+00   5.438035e+07    195s
# 2026-07-14 05:43:24,135 - INFO -   173652    4.6790859e+04   0.000000e+00   8.371429e+05    200s
# 2026-07-14 05:43:29,097 - INFO -   177679    4.6748348e+04   0.000000e+00   5.777444e+07    205s
# 2026-07-14 05:43:34,127 - INFO -   181446    4.6669650e+04   0.000000e+00   5.817361e+07    210s
# 2026-07-14 05:43:39,107 - INFO -   184479    4.6585248e+04   0.000000e+00   4.366789e+08    215s
# 2026-07-14 05:43:44,080 - INFO -   187355    4.6638258e+04   7.866356e-02   1.095761e+11    220s
# 2026-07-14 05:43:49,195 - INFO -   189005    4.6655116e+04   4.303774e-02   1.832897e+10    225s
# 2026-07-14 05:43:54,205 - INFO -   190565    4.6655116e+04   4.303775e-02   1.832897e+10    230s
# 2026-07-14 05:43:59,214 - INFO -   192125    4.6655116e+04   4.303774e-02   1.832897e+10    235s
# 2026-07-14 05:44:04,227 - INFO -   193565    4.6655116e+04   4.303775e-02   1.832897e+10    240s
# 2026-07-14 05:44:09,292 - INFO -   195125    4.6655116e+04   4.303774e-02   1.832897e+10    245s
# 2026-07-14 05:44:14,323 - INFO -   196685    4.6655116e+04   4.303774e-02   1.832897e+10    250s
# 2026-07-14 05:44:19,310 - INFO -   198245    4.6655116e+04   4.303774e-02   1.832897e+10    255s
# 2026-07-14 05:44:24,121 - INFO -   201029   -1.7199973e+36   8.110455e+38   1.719997e+06    260s
# 2026-07-14 05:44:29,147 - INFO -   204766   -4.1959978e+34   8.333769e+37   4.195998e+04    265s
# 2026-07-14 05:44:34,083 - INFO -   208092   -3.8138307e+34   5.878327e+37   3.813831e+04    270s
# 2026-07-14 05:44:39,108 - INFO -   212132   -1.1868575e+34   3.478720e+38   1.186858e+04    275s
# 2026-07-14 05:44:44,154 - INFO -   216879   -1.1674278e+34   5.542184e+37   1.167429e+04    280s

# %% [markdown]
# ### Inspect Infeasible solutions (if found)

# %%
# import gurobipy as gp
# m = gp.read('data/clews_data/clews_build_data/Model_Kotzur/Base_CNZ_noCCS/Base_CNZ_noCCS.lp')
# m.setParam('DualReductions', 0)
# m.optimize()
# if m.Status == gp.GRB.INFEASIBLE:
#     m.computeIIS()
#     m.write(f'vis/{model_builder_args["run_scenario"]}/{bcnexusRun.timeslices}ts_{RUNTAG}/infeasible.ilp')   # constraint names in this file name the exact conflict
#     utils.print_banner(f'Infeasible model detected. Infeasibility report written to vis/{model_builder_args["run_scenario"]}/{bcnexusRun.timeslices}ts_{RUNTAG}/infeasible.ilp')

# %% [markdown]
# # <span style="color: Coral;"> Results </span>

# %% [markdown]
# ### <span style="color: grey;"> Check Results @ `results\clews\<Model_<storage_algorithm>_<scenario>`</span>

# %% [markdown]
# ## Get RESULTS in csvs

# %%
results_path=bcnexusRun.get_result_csvs(debug_mode=True)

# %% [markdown]
# - <span style="color: grey;"> We can also use the `datapackage` module's `GetDataPackage` object to load load the results as an object.
# - <span style="color: grey;"> This results pack could be used for __post-analysis, result exchange to other models, visualizations, scenario dashes__ etc.

# %% [markdown]
# - <span style="color: grey;">  Get `result_pack` as an instance of `GetDataPackage` object

# %%
from bcnexus.clews.datapackage import GetDataPackage

nexus_results_root=f'results/clews/Model_{model_builder_args['storage_algorithm']}_{model_builder_args['run_scenario']}/{timeslices_int}ts_{RUNTAG}/{timeslices_int}ts_csvs_gurobi_{RUNTAG}'
result_pack=GetDataPackage(nexus_results_root)
result_pack.show

# %% [markdown]
# - <span style="color: grey;">  Apply `get_dataframe(<Result param name>)` method of the `result_pack` instance

# %%
#example
result_pack.get_dataframe('CapitalInvestment')

# %% [markdown]
# # <span style="color: yellow;"> Plots </span>

# %% [markdown]
# !! <span style="color: biege;"> Still under active development to include more comprehensive plots <span style="color: yellow;"> EL_20251119

# %% [markdown]
# - <span style="color: biege;">  Load the `plotter` module.
#   - <span style="color: grey;"> plotter.`get_plots()` function returns a dictionary of plots. You can review the plots in this notebook from that dictionary. The function also save the plots as html to 'vis/bccm/< scenario > '

# %% [markdown]
# - Complete workflow to create and save plots to defined path

# %%
from pathlib import Path
import bcnexus.plots as plotter

plotter.main(nexus_scenario=model_builder_args['run_scenario'],
             storage_algorithm=model_builder_args['storage_algorithm'],
             timeslices=bcnexusRun.timeslices,
             results_csvs=results_path,
             plots_save_to=Path(f'vis/{model_builder_args["run_scenario"]}/{bcnexusRun.timeslices}ts_{RUNTAG}'),)

# %% [markdown]
# - Loading _nexus_plots_ as a dictionary of plot

# %%
plotter_args=dict(
    nexus_scenario=model_builder_args['run_scenario'],
    storage_algorithm=model_builder_args['storage_algorithm'],
    timeslices=timeslices_int,
    results_csvs=nexus_results_root,
    plots_save_to=Path(f'vis/{model_builder_args["run_scenario"]}/{timeslices_int}ts_{RUNTAG}')
)
# plotter.main(**plotter_args)
nexus_plots=plotter.get_plots(**plotter_args)

# %% [markdown]
# - example on how to see plots inside _nexus_plots_ dict

# %%
nexus_plots['Energy'].keys()

# %%
nexus_plots['Energy']['power_generation_annual']

# %% [markdown]
# # <span style="color: Coral;"> Playground for Solved Model </span>

# %% [markdown]
# * <span style="color: grey;">Load the Gurobi Model object as `m` from `clewsRun`'s attribute `solved_model` </span>

# %%
m=bcnexusRun.solved_model

# %%
m.printStats()          # Print basic stats: number of vars, constraints, etc.

# %%
m.getAttr('Obj')     # Get objective coefficients

# %%
m.getConstrs()          # List of all constraint objects

# %% [markdown]
# #### <span style="color: orange;">  Define or Modify the Model </span>

# %%
# x = m.addVar(lb=0, ub=10, obj=3, name='x')
# y = m.addVar(lb=0, ub=GRB.INFINITY, obj=1, name='y')
# m.addConstr(2*x + 3*y >= 10, name='demand_constraint')
# m.setObjective(3*x + 1*y, GRB.MINIMIZE)

# %% [markdown]
# * <span style="color: grey;">Load the `plotter` module and use the `main()` function </span>
